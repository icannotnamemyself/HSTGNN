# %%
# %env DATASET=solar_AL
# %env NUM_NODES=137
# %env ROOT=/notebooks/MTGNN
# Out:
# env: DATASET=solar_AL
# env: NUM_NODES=137
# env: ROOT=/notebooks/MTGNN

# %%
# %env HORIZON=3
# %env PYTHONPATH=/notebooks/pytorch_timeseries
# %env PYTHONUNBUFFERED=1
# !python ../mtgnn_train_single_step.py  --horizon ${HORIZON} --data ${ROOT}/data/${DATASET}.txt  --save model/${DATASET}_horizon_${HORIZON}.pt --device cuda:3 --gcn_true False --num_nodes ${NUM_NODES}  --epochs 30 --skip_layer False --skip_channels 16
# Out:
# env: HORIZON=3
# env: PYTHONPATH=/notebooks/pytorch_timeseries
# 2022-10-14 15:03:30.418 | INFO     | __main__:<module>:149 - running for dataset:solar_AL
# 2022-10-14 15:03:30.482 | INFO     | __main__:<module>:242 - current runs: 0, total runs:10
# Namespace(L1Loss=True, batch_size=32, buildA_true=True, clip=5, conv_channels=16, data='/notebooks/MTGNN/data/solar_AL.txt', device='cuda:3', dilation_exponential=2, dropout=0.3, end_channels=64, epochs=30, gcn_depth=2, gcn_true=False, horizon=3, in_dim=1, layers=5, log_interval=2000, lr=0.001, node_dim=40, normalize=2, num_nodes=137, num_split=1, optim='adam', propalpha=0.05, residual_channels=16, residual_layer=True, run=10, save='model/solar_AL_horizon_3.pt', seq_in_len=168, seq_out_len=1, skip_channels=16, skip_layer=False, step_size=100, subgraph_size=20, tanhalpha=3, weight_decay=1e-05)
# The recpetive field size is 187
# Number of model parameters is 28465
# ...

# %%
# %env HORIZON=6
# %env PYTHONPATH=/notebooks/pytorch_timeseries
# %env PYTHONUNBUFFERED=1
# !python ../mtgnn_train_single_step.py  --horizon ${HORIZON} --data ${ROOT}/data/${DATASET}.txt  --save model/${DATASET}_horizon_${HORIZON}.pt --device cuda:3 --gcn_true False --num_nodes ${NUM_NODES}  --epochs 30 --skip_layer False --skip_channels 16
# Out:
# env: HORIZON=6
# env: PYTHONPATH=/notebooks/pytorch_timeseries
# env: PYTHONUNBUFFERED=1
# Oct 16 05:15:02 Jupyter [73248]: running for dataset:solar_AL
# Oct 16 05:15:02 Jupyter [73248]: current runs: 0, total runs:10
# Oct 16 05:15:02 Jupyter [73248]: Namespace(L1Loss=True, batch_size=32, buildA_true=True, clip=5, conv_channels=16, data='/notebooks/MTGNN/data/solar_AL.txt', device='cuda:3', dilation_exponential=2, dropout=0.3, end_channels=64, epochs=30, gcn_depth=2, gcn_true=False, horizon=6, in_dim=1, layers=5, log_interval=2000, lr=0.001, node_dim=40, normalize=2, num_nodes=137, num_split=1, optim='adam', propalpha=0.05, residual_channels=16, residual_layer=True, run=10, save='model/solar_AL_horizon_6.pt', seq_in_len=168, seq_out_len=1, skip_channels=16, skip_layer=False, step_size=100, subgraph_size=20, tanhalpha=3, weight_decay=1e-05)
# Oct 16 05:15:12 Jupyter [73248]: The recpetive field size is 187
# Oct 16 05:15:12 Jupyter [73248]: Number of model parameters is 28465
# ...

# %%
# %env HORIZON=12
# %env PYTHONPATH=/notebooks/pytorch_timeseries
# %env PYTHONUNBUFFERED=1
# !python ../mtgnn_train_single_step.py  --horizon ${HORIZON} --data ${ROOT}/data/${DATASET}.txt  --save model/${DATASET}_horizon_${HORIZON}.pt --device cuda:3 --gcn_true False --num_nodes ${NUM_NODES}  --epochs 30 --skip_layer False --skip_channels 16
# Out:
# env: HORIZON=12
# env: PYTHONPATH=/notebooks/pytorch_timeseries
# env: PYTHONUNBUFFERED=1
# Oct 19 02:41:00 Jupyter [84791]: running for dataset:solar_AL
# Oct 19 02:41:00 Jupyter [84791]: current runs: 0, total runs:10
# Oct 19 02:41:00 Jupyter [84791]: Namespace(L1Loss=True, batch_size=32, buildA_true=True, clip=5, conv_channels=16, data='/notebooks/MTGNN/data/solar_AL.txt', device='cuda:3', dilation_exponential=2, dropout=0.3, end_channels=64, epochs=30, gcn_depth=2, gcn_true=False, horizon=12, in_dim=1, layers=5, log_interval=2000, lr=0.001, node_dim=40, normalize=2, num_nodes=137, num_split=1, optim='adam', propalpha=0.05, residual_channels=16, residual_layer=True, run=10, save='model/solar_AL_horizon_12.pt', seq_in_len=168, seq_out_len=1, skip_channels=16, skip_layer=False, step_size=100, subgraph_size=20, tanhalpha=3, weight_decay=1e-05)
# Oct 19 02:41:08 Jupyter [84791]: The recpetive field size is 187
# Oct 19 02:41:08 Jupyter [84791]: Number of model parameters is 28465
# ...

# %%
# %env HORIZON=24
# %env PYTHONPATH=/notebooks/pytorch_timeseries
# %env PYTHONUNBUFFERED=1
# !python ../mtgnn_train_single_step.py  --horizon ${HORIZON} --data ${ROOT}/data/${DATASET}.txt  --save model/${DATASET}_horizon_${HORIZON}.pt --device cuda:3 --gcn_true False --num_nodes ${NUM_NODES}  --epochs 30 --skip_layer False --skip_channels 16
# Out:
# env: HORIZON=24
# env: PYTHONPATH=/notebooks/pytorch_timeseries
# env: PYTHONUNBUFFERED=1
# Oct 21 01:23:53 Jupyter [87322]: running for dataset:solar_AL
# Oct 21 01:23:53 Jupyter [87322]: current runs: 0, total runs:10
# Oct 21 01:23:53 Jupyter [87322]: Namespace(L1Loss=True, batch_size=32, buildA_true=True, clip=5, conv_channels=16, data='/notebooks/MTGNN/data/solar_AL.txt', device='cuda:3', dilation_exponential=2, dropout=0.3, end_channels=64, epochs=30, gcn_depth=2, gcn_true=False, horizon=24, in_dim=1, layers=5, log_interval=2000, lr=0.001, node_dim=40, normalize=2, num_nodes=137, num_split=1, optim='adam', propalpha=0.05, residual_channels=16, residual_layer=True, run=10, save='model/solar_AL_horizon_24.pt', seq_in_len=168, seq_out_len=1, skip_channels=16, skip_layer=False, step_size=100, subgraph_size=20, tanhalpha=3, weight_decay=1e-05)
# Oct 21 01:24:03 Jupyter [87322]: The recpetive field size is 187
# Oct 21 01:24:03 Jupyter [87322]: Number of model parameters is 28465
# ...
