# %%
# %env DATASET=solar_AL
# %env NUM_NODES=137
# %env ROOT=/notebooks/MTGNN
# Out:
# env: DATASET=solar_AL
# env: NUM_NODES=137
# env: ROOT=/notebooks/MTGNN

# %%
# %env HORIZON=3
# %env PYTHONUNBUFFERED=1
# %env PYTHONPATH=/notebooks/pytorch_timeseries
# !python ../mtgnn_train_single_step.py  --horizon ${HORIZON} --data ${ROOT}/data/${DATASET}.txt  --save model/${DATASET}_horizon_${HORIZON}.pt --device cuda:0 --gcn_true False --residual_layer False --num_nodes ${NUM_NODES}  --epochs 30 --skip_layer False --skip_channels 16
# Out:
# env: HORIZON=3
# env: PYTHONPATH=/notebooks/pytorch_timeseries
# 2022-10-14 11:52:55.970 | INFO     | __main__:<module>:149 - running for dataset:solar_AL
# 2022-10-14 11:52:56.041 | INFO     | __main__:<module>:242 - current runs: 0, total runs:10
# Namespace(L1Loss=True, batch_size=32, buildA_true=True, clip=5, conv_channels=16, data='/notebooks/MTGNN/data/solar_AL.txt', device='cuda:0', dilation_exponential=2, dropout=0.3, end_channels=64, epochs=30, gcn_depth=2, gcn_true=False, horizon=3, in_dim=1, layers=5, log_interval=2000, lr=0.001, node_dim=40, normalize=2, num_nodes=137, num_split=1, optim='adam', propalpha=0.05, residual_channels=16, residual_layer=False, run=10, save='model/solar_AL_horizon_3.pt', seq_in_len=168, seq_out_len=1, skip_channels=16, skip_layer=False, step_size=100, subgraph_size=20, tanhalpha=3, weight_decay=1e-05)
# The recpetive field size is 187
# Number of model parameters is 27105
# ...

# %%
# %env HORIZON=6
# %env PYTHONUNBUFFERED=1
# %env PYTHONPATH=/notebooks/pytorch_timeseries
# !python ../mtgnn_train_single_step.py  --horizon ${HORIZON} --data ${ROOT}/data/${DATASET}.txt  --save model/${DATASET}_horizon_${HORIZON}.pt --device cuda:0 --gcn_true False --residual_layer False --num_nodes ${NUM_NODES}  --epochs 30 --skip_layer False --skip_channels 16
# Out:
# env: HORIZON=6
# env: PYTHONUNBUFFERED=1
# env: PYTHONPATH=/notebooks/pytorch_timeseries
# Oct 16 05:18:57 Jupyter [74612]: running for dataset:solar_AL
# Oct 16 05:18:57 Jupyter [74612]: current runs: 0, total runs:10
# Oct 16 05:18:57 Jupyter [74612]: Namespace(L1Loss=True, batch_size=32, buildA_true=True, clip=5, conv_channels=16, data='/notebooks/MTGNN/data/solar_AL.txt', device='cuda:0', dilation_exponential=2, dropout=0.3, end_channels=64, epochs=30, gcn_depth=2, gcn_true=False, horizon=6, in_dim=1, layers=5, log_interval=2000, lr=0.001, node_dim=40, normalize=2, num_nodes=137, num_split=1, optim='adam', propalpha=0.05, residual_channels=16, residual_layer=False, run=10, save='model/solar_AL_horizon_6.pt', seq_in_len=168, seq_out_len=1, skip_channels=16, skip_layer=False, step_size=100, subgraph_size=20, tanhalpha=3, weight_decay=1e-05)
# Oct 16 05:19:11 Jupyter [74612]: The recpetive field size is 187
# Oct 16 05:19:11 Jupyter [74612]: Number of model parameters is 27105
# ...

# %%
# %env HORIZON=12
# %env PYTHONUNBUFFERED=1
# %env PYTHONPATH=/notebooks/pytorch_timeseries
# !python ../mtgnn_train_single_step.py  --horizon ${HORIZON} --data ${ROOT}/data/${DATASET}.txt  --save model/${DATASET}_horizon_${HORIZON}.pt --device cuda:0 --gcn_true False --residual_layer False --num_nodes ${NUM_NODES}  --epochs 30 --skip_layer False --skip_channels 16
# Out:
# env: HORIZON=12
# env: PYTHONUNBUFFERED=1
# env: PYTHONPATH=/notebooks/pytorch_timeseries
# Oct 17 07:12:19 Jupyter [77060]: running for dataset:solar_AL
# Oct 17 07:12:19 Jupyter [77060]: current runs: 0, total runs:10
# Oct 17 07:12:19 Jupyter [77060]: Namespace(L1Loss=True, batch_size=32, buildA_true=True, clip=5, conv_channels=16, data='/notebooks/MTGNN/data/solar_AL.txt', device='cuda:0', dilation_exponential=2, dropout=0.3, end_channels=64, epochs=30, gcn_depth=2, gcn_true=False, horizon=12, in_dim=1, layers=5, log_interval=2000, lr=0.001, node_dim=40, normalize=2, num_nodes=137, num_split=1, optim='adam', propalpha=0.05, residual_channels=16, residual_layer=False, run=10, save='model/solar_AL_horizon_12.pt', seq_in_len=168, seq_out_len=1, skip_channels=16, skip_layer=False, step_size=100, subgraph_size=20, tanhalpha=3, weight_decay=1e-05)
# Oct 17 07:12:32 Jupyter [77060]: The recpetive field size is 187
# Oct 17 07:12:32 Jupyter [77060]: Number of model parameters is 27105
# ...

# %%
# %env HORIZON=24
# %env PYTHONUNBUFFERED=1
# %env PYTHONPATH=/notebooks/pytorch_timeseries
# !python ../mtgnn_train_single_step.py  --horizon ${HORIZON} --data ${ROOT}/data/${DATASET}.txt  --save model/${DATASET}_horizon_${HORIZON}.pt --device cuda:0 --gcn_true False --residual_layer False --num_nodes ${NUM_NODES}  --epochs 30 --skip_layer False --skip_channels 16
# Out:
# env: HORIZON=24
# env: PYTHONUNBUFFERED=1
# env: PYTHONPATH=/notebooks/pytorch_timeseries
# Oct 18 02:01:25 Jupyter [79928]: running for dataset:solar_AL
# Oct 18 02:01:25 Jupyter [79928]: current runs: 0, total runs:10
# Oct 18 02:01:25 Jupyter [79928]: Namespace(L1Loss=True, batch_size=32, buildA_true=True, clip=5, conv_channels=16, data='/notebooks/MTGNN/data/solar_AL.txt', device='cuda:0', dilation_exponential=2, dropout=0.3, end_channels=64, epochs=30, gcn_depth=2, gcn_true=False, horizon=24, in_dim=1, layers=5, log_interval=2000, lr=0.001, node_dim=40, normalize=2, num_nodes=137, num_split=1, optim='adam', propalpha=0.05, residual_channels=16, residual_layer=False, run=10, save='model/solar_AL_horizon_24.pt', seq_in_len=168, seq_out_len=1, skip_channels=16, skip_layer=False, step_size=100, subgraph_size=20, tanhalpha=3, weight_decay=1e-05)
# Oct 18 02:01:36 Jupyter [79928]: The recpetive field size is 187
# Oct 18 02:01:36 Jupyter [79928]: Number of model parameters is 27105
# ...
